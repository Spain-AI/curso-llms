# %% [markdown]
# # Manual prompting with ChatGPT

# %% [markdown]
# ## Load data

# %%
import yfinance as yf

stocks = ['SAN', 'TEF.MC']
df_base = yf.download(stocks, start='2010-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df_base
# Out:
# Price          Close                High                 Low            \
# Ticker           SAN    TEF.MC       SAN    TEF.MC       SAN    TEF.MC
# Date
# 2010-01-04  7.052265  7.151775  7.085609  7.151775  6.989745  7.063371
# 2010-01-05  7.143964  7.140949  7.181476  7.162599  7.068940  7.113887
# ...              ...       ...       ...       ...       ...       ...
# 2025-04-09  6.310000  3.889000  6.360000  4.038000  5.810000  3.833000
# 2025-04-10       NaN  3.980000       NaN  4.229000       NaN  3.933000
#
# Price           Open                Volume
# Ticker           SAN    TEF.MC         SAN      TEF.MC
# Date
# 2010-01-04  6.993913  7.063371   2166000.0  21545258.0
# 2010-01-05  7.139796  7.151774   2169300.0  20230384.0
# ...              ...       ...         ...         ...
# 2025-04-09  5.880000  4.011000  20287100.0  28947892.0
# 2025-04-10       NaN  4.229000         NaN   7880321.0
#
# [3945 rows x 10 columns]

# %% [markdown]
# ## Calculate metrics

# %%
df = df_base['Close']

df = (df
 .loc['2010':]
 .groupby(df.index.year).pct_change(fill_method=None).add(1)
 .groupby(df.index.year).cumprod().sub(1)
 .resample('1YE').last()
 .mul(100)
)

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_b47e3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Ticker</th>
#       <th id="T_b47e3_level0_col0" class="col_heading level0 col0" >SAN</th>
#       <th id="T_b47e3_level0_col1" class="col_heading level0 col1" >TEF.MC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b47e3_level0_row0" class="row_heading level0 row0" >2010-12-31 00:00:00</th>
#       <td id="T_b47e3_row0_col0" class="data row0 col0" >-31.366285</td>
#       <td id="T_b47e3_row0_col1" class="data row0 col1" >-8.348665</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row1" class="row_heading level0 row1" >2011-12-31 00:00:00</th>
#       <td id="T_b47e3_row1_col0" class="data row1 col0" >-17.717052</td>
#       <td id="T_b47e3_row1_col1" class="data row1 col1" >-13.896580</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row2" class="row_heading level0 row2" >2012-12-31 00:00:00</th>
#       <td id="T_b47e3_row2_col0" class="data row2 col0" >26.470395</td>
#       <td id="T_b47e3_row2_col1" class="data row2 col1" >-16.356645</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row3" class="row_heading level0 row3" >2013-12-31 00:00:00</th>
#       <td id="T_b47e3_row3_col0" class="data row3 col0" >12.884445</td>
#       <td id="T_b47e3_row3_col1" class="data row3 col1" >13.810783</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row4" class="row_heading level0 row4" >2014-12-31 00:00:00</th>
#       <td id="T_b47e3_row4_col0" class="data row4 col0" >4.013052</td>
#       <td id="T_b47e3_row4_col1" class="data row4 col1" >7.988953</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row5" class="row_heading level0 row5" >2015-12-31 00:00:00</th>
#       <td id="T_b47e3_row5_col0" class="data row5 col0" >-35.479623</td>
#       <td id="T_b47e3_row5_col1" class="data row5 col1" >-7.780663</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row6" class="row_heading level0 row6" >2016-12-31 00:00:00</th>
#       <td id="T_b47e3_row6_col0" class="data row6 col0" >21.352160</td>
#       <td id="T_b47e3_row6_col1" class="data row6 col1" >-4.754042</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row7" class="row_heading level0 row7" >2017-12-31 00:00:00</th>
#       <td id="T_b47e3_row7_col0" class="data row7 col0" >32.436527</td>
#       <td id="T_b47e3_row7_col1" class="data row7 col1" >-4.592581</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row8" class="row_heading level0 row8" >2018-12-31 00:00:00</th>
#       <td id="T_b47e3_row8_col0" class="data row8 col0" >-22.770240</td>
#       <td id="T_b47e3_row8_col1" class="data row8 col1" >-6.188420</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row9" class="row_heading level0 row9" >2019-12-31 00:00:00</th>
#       <td id="T_b47e3_row9_col0" class="data row9 col0" >2.632217</td>
#       <td id="T_b47e3_row9_col1" class="data row9 col1" >-8.734656</td>
#     </tr>
#     <tr>
#       <th id="T_b47e3_level0_row10" class="row_heading level0 row10" >2020-12-31 00:00:00</th>
#       <td id="T_b47e3_row10_col0" class="data row10 col0" >-31.062117</td>
#       <td id="T_b47e3_row10_col1" class="data row10 col1" >-44.842659</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Interpretation with AI
#
# 1. Copy table to clipboard
# 2. Create a prompt for ChatGPT in [this folder](../prompts/README.md)
# 3. Paste table into ChatGPT, along with the prompt
# 4. Paste the response below

# %% [markdown]
# Aquí están algunas explicaciones sobre los valores más significativos, tanto positivos como negativos, en los retornos acumulados anuales de los activos financieros, respaldados por noticias:
#
# 1. **Apple (AAPL) 2010-2020**:
#    - **2010 (50.72%)**: Apple tuvo un excelente año debido al lanzamiento del iPhone 4 y el iPad original, ambos revolucionarios en sus respectivas categorías. Estos productos incrementaron significativamente las ventas y los ingresos de la compañía【7†source】.
#    - **2014 (42.63%)**: En este año, Apple realizó una división de acciones 7:1 en junio, lo que hizo que sus acciones fueran más accesibles para los inversores. Además, el lanzamiento del iPhone 6 y 6 Plus impulsó las ventas a nuevos récords【8†source】【16†source】.
#    - **2020 (79.62%)**: En medio de la pandemia de COVID-19, Apple lanzó el iPhone 12 con tecnología 5G y experimentó un aumento significativo en la demanda de sus productos y servicios debido al aumento del trabajo y estudio desde casa【15†source】【17†source】.
#
# 2. **Tesla (TSLA) 2020 (707.40%)**:
#    - Tesla tuvo un crecimiento impresionante en 2020 impulsado por varios factores, incluyendo su inclusión en el índice S&P 500, lo cual atrajo una gran cantidad de inversiones. Además, reportó entregas récord de vehículos y continuó expandiéndose en nuevos mercados【16†source】.
#
# 3. **Amazon (AMZN) 2015 (119.07%)**:
#    - Amazon experimentó un aumento significativo en 2015 gracias al rápido crecimiento de Amazon Web Services (AWS), que se convirtió en un importante motor de ingresos. El evento Prime Day también contribuyó al incremento en las ventas y al rendimiento positivo de las acciones【15†source】.
#
# 4. **Meta (META) 2013 (95.18%)**:
#    - En 2013, Facebook (ahora Meta) tuvo un año excepcional debido a su salida a bolsa y su creciente popularidad y expansión global. La compañía también comenzó a monetizar su plataforma móvil de manera más efectiva, lo que impulsó los ingresos y el precio de sus acciones【15†source】.
#
# 5. **Microsoft (MSFT) 2019 (58.26%)**:
#    - Microsoft tuvo un gran desempeño en 2019 gracias al crecimiento continuo de sus servicios en la nube, especialmente Azure, que se convirtió en un motor clave de ingresos. También se beneficiaron de la expansión de su suite Office 365 y la adquisición de GitHub【15†source】.
#
# Estos eventos reflejan cómo los lanzamientos de productos innovadores, las estrategias empresariales y los cambios en el mercado pueden influir significativamente en los retornos de las acciones. Para más detalles, puedes consultar las siguientes fuentes:
# - [Apple Historical Data](https://www.nasdaq.com)
# - [Apple Stock News](https://stockanalysis.com)
# - [Apple Stock Price History](https://markets.businessinsider.com)
